# %% [markdown]
# <a href="https://colab.research.google.com/github/abortey1/Andrew-Bortey-repository/blob/main/College_Basketball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_college_2012 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb.csv')
df_college_2013 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb13.csv')
df_college_2014 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb14.csv')
df_college_2015 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb15.csv')
df_college_2016 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb16.csv')
df_college_2017 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb17.csv')
df_college_2018 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb18.csv')
df_college_2019 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb19.csv')
df_college_2020 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb20.csv')
df_college_2021 = pd.read_csv('https://github.com/abortey1/college-basketbal/raw/main/cbb21.csv')

# %% [markdown]
# I picked this data set because I am interested in college basketball.
# Go ILLINI!!
# I am interested in viewing the stats of the 2013 to 2021 season. I want to see what I can learn from it as there are many variables that I never considered thinking about when it came to the basketball season.
#
# More specifically, I want to know which team out of the years had the highest/lowest turnover percentage.
# I want to know which team won the most amount of games in 2017 - 2021.
# I want to know which team had the best fielg goal percentage from 2019-2021.

# %%
df_college_2012
# Out:
#                     TEAM  CONF   G   W  ...   WAB  POSTSEASON  SEED  YEAR
# 0         North Carolina   ACC  40  33  ...   8.6         2ND   1.0  2016
# 1              Wisconsin   B10  40  36  ...  11.3         2ND   1.0  2015
# 2               Michigan   B10  40  33  ...   6.9         2ND   3.0  2018
# 3             Texas Tech   B12  38  31  ...   7.0         2ND   3.0  2019
# 4                Gonzaga   WCC  39  37  ...   7.7         2ND   1.0  2017
# ...                  ...   ...  ..  ..  ...   ...         ...   ...   ...
# 2450        Michigan St.   B10  35  26  ...   6.7         S16   3.0  2013
# 2451             Arizona   P12  35  27  ...   4.6         S16   6.0  2013
# 2452              Oregon   P12  37  28  ...   2.9         S16  12.0  2013
# 2453            La Salle   A10  34  24  ...   0.3         S16  13.0  2013
# 2454  Florida Gulf Coast  ASun  35  24  ...  -4.0         S16  15.0  2013
#
# [2455 rows x 24 columns]

# %%
df_college_2013
# Out:
#                     TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0                Indiana   B10  36  29  ...   67.8   7.8         S16   1.0
# 1                Gonzaga   WCC  34  31  ...   65.1   7.6         R32   1.0
# 2                 Kansas   B12  37  31  ...   67.7   7.5         S16   1.0
# 3             Louisville    BE  40  35  ...   67.1   9.0   Champions   1.0
# 4             Georgetown    BE  32  25  ...   62.5   6.6         R64   2.0
# ..                   ...   ...  ..  ..  ...    ...   ...         ...   ...
# 342     Prairie View A&M  SWAC  31  12  ...   67.0 -15.1         NaN   NaN
# 343              Buffalo   MAC  32  12  ...   65.4 -13.6         NaN   NaN
# 344  Louisiana Lafayette    SB  32  12  ...   70.2 -13.9         NaN   NaN
# 345      Bethune Cookman  MEAC  32  12  ...   65.9 -15.0         NaN   NaN
# 346                 Troy    SB  33  12  ...   61.1 -16.6         NaN   NaN
#
# [347 rows x 23 columns]

# %%
df_college_2014
# Out:
#                TEAM  CONF   G   W  ADJOE  ...  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 0           Arizona   P12  38  33  116.2  ...  32.0   64.3   9.4          E8   1.0
# 1           Florida   SEC  39  36  115.9  ...  33.0   63.1  11.7          F4   1.0
# 2          Virginia   ACC  37  30  114.6  ...  32.3   61.2   8.2         S16   1.0
# 3       Wichita St.   MVC  35  34  116.4  ...  31.1   65.1   8.1         R32   1.0
# 4            Kansas   B12  35  25  119.2  ...  35.5   68.2   6.9         R32   2.0
# ..              ...   ...  ..  ..    ...  ...   ...    ...   ...         ...   ...
# 346        Winthrop  BSth  30  17  103.2  ...  36.4   66.2  -8.2         NaN   NaN
# 347      Wright St.  Horz  34  19   99.5  ...  33.0   65.2  -8.1         NaN   NaN
# 348         Wyoming   MWC  31  16  104.9  ...  31.6   61.1  -5.7         NaN   NaN
# 349            Yale   Ivy  32  18  101.5  ...  36.3   65.2  -6.0         NaN   NaN
# ...

# %%
df_college_2015
# Out:
#               TEAM CONF   G   W  ADJOE  ...  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 0        Wisconsin  B10  40  36  129.1  ...  37.5   59.3  11.3         2ND   1.0
# 1             Duke  ACC  39  35  125.2  ...  31.4   66.4  10.7   Champions   1.0
# 2          Arizona  P12  38  34  117.5  ...  33.5   66.7   9.0          E8   2.0
# 3          Gonzaga  WCC  37  34  120.2  ...  33.0   65.2   7.8          E8   2.0
# 4       Louisville  ACC  36  27  109.4  ...  30.3   65.6   5.8          E8   4.0
# ..             ...  ...  ..  ..    ...  ...   ...    ...   ...         ...   ...
# 346           UCLA  P12  36  22  111.8  ...  35.6   66.8   0.0         S16  11.0
# 347           Utah  P12  34  25  114.9  ...  31.2   61.4   3.7         S16   5.0
# 348  West Virginia  B12  35  25  110.3  ...  36.5   68.6   4.1         S16   5.0
# 349    Wichita St.  MVC  34  29  114.3  ...  35.3   62.6   4.2         S16   7.0
# 350         Xavier   BE  37  23  115.7  ...  34.6   65.5   1.3         S16   6.0
#
# ...

# %%
df_college_2016
# Out:
#                   TEAM  CONF   G   W  ADJOE  ...  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 0    Abilene Christian  Slnd  27   9   96.3  ...  36.9   68.4 -14.4         NaN   NaN
# 1            Air Force   MWC  30  12   98.1  ...  34.9   67.9 -10.9         NaN   NaN
# 2                Akron   MAC  34  25  109.0  ...  30.1   68.3  -1.4         NaN   NaN
# 3              Alabama   SEC  33  18  105.4  ...  32.9   65.7  -0.6         NaN   NaN
# 4          Alabama A&M  SWAC  28  10   98.3  ...  32.1   66.2 -15.1         NaN   NaN
# ..                 ...   ...  ..  ..    ...  ...   ...    ...   ...         ...   ...
# 346         Wright St.  Horz  33  20  100.4  ...  33.0   66.3  -6.1         NaN   NaN
# 347            Wyoming   MWC  30  12  108.3  ...  35.4   65.6 -10.6         NaN   NaN
# 348             Xavier    BE  34  28  117.0  ...  31.1   72.4   7.7         R32   2.0
# 349               Yale   Ivy  29  22  109.1  ...  32.7   66.8  -0.1         R32  12.0
# ...

# %%
df_college_2017
# Out:
#                     TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0                Gonzaga   WCC  39  37  ...   71.5   7.7         2ND   1.0
# 1         North Carolina   ACC  39  33  ...   72.8   8.4   Champions   1.0
# 2              Villanova    BE  36  32  ...   65.6  11.1         R32   1.0
# 3                 Kansas   B12  36  31  ...   71.4  11.0          E8   1.0
# 4               Kentucky   SEC  38  32  ...   73.7   9.0          E8   2.0
# ..                   ...   ...  ..  ..  ...    ...   ...         ...   ...
# 346             Longwood  BSth  28   6  ...   71.8 -19.5         NaN   NaN
# 347   North Carolina A&T  MEAC  30   3  ...   64.6 -25.2         NaN   NaN
# 348  Arkansas Pine Bluff  SWAC  30   6  ...   69.0 -20.2         NaN   NaN
# 349         Presbyterian  BSth  28   5  ...   65.3 -20.5         NaN   NaN
# 350          Alabama A&M  SWAC  29   2  ...   65.7 -24.0         NaN   NaN
#
# [351 rows x 23 columns]

# %%
df_college_2018
# Out:
#                        TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0                 Villanova    BE  40  36  ...   69.6  10.6   Champions   1.0
# 1                  Virginia   ACC  34  31  ...   60.5  11.3         R64   1.0
# 2                      Duke   ACC  37  29  ...   70.9   6.6          E8   2.0
# 3                    Purdue   B10  37  30  ...   68.7   7.6         S16   2.0
# 4                Cincinnati  Amer  36  31  ...   66.2   5.9         R32   2.0
# ..                      ...   ...  ..  ..  ...    ...   ...         ...   ...
# 346              Coppin St.  MEAC  32   5  ...   68.7 -20.9         NaN   NaN
# 347  Mississippi Valley St.  SWAC  32   4  ...   69.9 -22.5         NaN   NaN
# 348  Maryland Eastern Shore  MEAC  30   7  ...   66.4 -19.3         NaN   NaN
# 349             Alabama A&M  SWAC  31   3  ...   67.5 -23.0         NaN   NaN
# 350            Delaware St.  MEAC  30   4  ...   66.2 -24.1         NaN   NaN
#
# [351 rows x 23 columns]

# %%
df_college_2019
# Out:
#                        TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0                   Gonzaga   WCC  37  33  ...   72.0   7.0          E8   1.0
# 1                  Virginia   ACC  38  35  ...   60.7  11.1   Champions   1.0
# 2                      Duke   ACC  38  32  ...   73.6  11.2          E8   1.0
# 3            North Carolina   ACC  36  29  ...   76.0  10.0         S16   1.0
# 4                  Michigan   B10  37  30  ...   65.9   9.2         S16   2.0
# ..                      ...   ...  ..  ..  ...    ...   ...         ...   ...
# 348              Alcorn St.  SWAC  27  10  ...   67.1 -16.7         NaN   NaN
# 349           New Hampshire    AE  27   5  ...   67.1 -20.2         NaN   NaN
# 350             Chicago St.   WAC  30   3  ...   71.9 -20.9         NaN   NaN
# 351            Delaware St.  MEAC  29   6  ...   71.6 -21.7         NaN   NaN
# 352  Maryland Eastern Shore  MEAC  30   7  ...   64.5 -19.9         NaN   NaN
#
# [353 rows x 23 columns]

# %%
df_college_2020
# Out:
#       RK                    TEAM  CONF   G   W  ...  2P_D  3P_O  3P_D  ADJ_T   WAB
# 0      1                  Kansas   B12  30  28  ...  42.4  34.1  30.5   67.4  10.8
# 1      2                  Baylor   B12  30  26  ...  44.4  35.1  31.1   66.2   8.5
# 2      3                 Gonzaga   WCC  33  31  ...  47.4  38.6  32.0   72.0   7.7
# 3      4                  Dayton   A10  31  29  ...  45.1  37.1  33.0   67.5   6.8
# 4      5            Michigan St.   B10  31  22  ...  43.4  34.8  28.7   69.3   5.2
# ..   ...                     ...   ...  ..  ..  ...   ...   ...   ...    ...   ...
# 348  349     Arkansas Pine Bluff  SWAC  29   4  ...  50.2  26.3  31.1   66.1 -20.0
# 349  350  Maryland Eastern Shore  MEAC  31   5  ...  51.3  25.0  33.7   67.7 -20.8
# 350  351  Mississippi Valley St.  SWAC  30   4  ...  55.5  29.4  34.1   77.4 -22.2
# 351  352            Kennesaw St.  ASun  29   1  ...  55.0  24.8  37.1   68.2 -21.8
# ...

# %%
df_college_2021
# Out:
#                  TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T  WAB  SEED
# 0            Michigan   B10  24  20  118.1  ...  38.7  33.5   66.9  7.2   1.0
# 1              Baylor   B12  24  22  123.2  ...  41.8  34.0   68.8  6.6   1.0
# 2            Illinois   B10  29  23  117.7  ...  37.6  32.7   70.7  8.9   1.0
# 3             Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6  8.5   1.0
# 4                Iowa   B10  29  21  123.5  ...  38.6  34.8   70.0  5.6   2.0
# ..                ...   ...  ..  ..    ...  ...   ...   ...    ...  ...   ...
# 342    Louisiana Tech  CUSA  27  21  102.7  ...  34.6  29.6   69.6 -1.7   NaN
# 343            Toledo   MAC  29  21  113.3  ...  37.7  29.5   69.1 -2.1   NaN
# 344               UAB  CUSA  27  22  102.5  ...  31.1  32.4   67.5 -2.7   NaN
# 345  Eastern Kentucky   OVC  27  22  101.5  ...  35.8  33.0   75.1 -3.8   NaN
# 346           Belmont   OVC  29  26  108.5  ...  34.7  34.0   71.1 -1.1   NaN
#
# [347 rows x 22 columns]

# %%
df_college_2021.dropna(['SEED'] == 'NaN')
# Out:
#                 TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T  WAB  SEED
# 0           Michigan   B10  24  20  118.1  ...  38.7  33.5   66.9  7.2   1.0
# 1             Baylor   B12  24  22  123.2  ...  41.8  34.0   68.8  6.6   1.0
# 2           Illinois   B10  29  23  117.7  ...  37.6  32.7   70.7  8.9   1.0
# 3            Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6  8.5   1.0
# 4               Iowa   B10  29  21  123.5  ...  38.6  34.8   70.0  5.6   2.0
# ..               ...   ...  ..  ..    ...  ...   ...   ...    ...  ...   ...
# 63  Mount St. Mary's   NEC  22  12   95.7  ...  33.7  30.1   62.2 -7.2  16.0
# 64          Hartford    AE  23  15   97.3  ...  32.7  28.7   66.9 -4.9  16.0
# 65       Norfolk St.  MEAC  21  16   99.4  ...  37.4  31.7   67.9 -5.0  16.0
# 66    Texas Southern  SWAC  23  16   97.3  ...  27.7  32.4   71.8 -4.5  16.0
# 67   Appalachian St.    SB  24  17   99.0  ...  32.6  33.5   65.4 -7.7  16.0
#
# [68 rows x 22 columns]

# %%
df_college_2020.dropna(['SEED'] == 'NaN')
# Out:
#       RK                    TEAM  CONF   G   W  ...  2P_D  3P_O  3P_D  ADJ_T   WAB
# 0      1                  Kansas   B12  30  28  ...  42.4  34.1  30.5   67.4  10.8
# 1      2                  Baylor   B12  30  26  ...  44.4  35.1  31.1   66.2   8.5
# 2      3                 Gonzaga   WCC  33  31  ...  47.4  38.6  32.0   72.0   7.7
# 3      4                  Dayton   A10  31  29  ...  45.1  37.1  33.0   67.5   6.8
# 4      5            Michigan St.   B10  31  22  ...  43.4  34.8  28.7   69.3   5.2
# ..   ...                     ...   ...  ..  ..  ...   ...   ...   ...    ...   ...
# 348  349     Arkansas Pine Bluff  SWAC  29   4  ...  50.2  26.3  31.1   66.1 -20.0
# 349  350  Maryland Eastern Shore  MEAC  31   5  ...  51.3  25.0  33.7   67.7 -20.8
# 350  351  Mississippi Valley St.  SWAC  30   4  ...  55.5  29.4  34.1   77.4 -22.2
# 351  352            Kennesaw St.  ASun  29   1  ...  55.0  24.8  37.1   68.2 -21.8
# ...

# %%
df_college_2019.dropna(['SEED'] == 'NaN')
# Out:
#                       TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0                  Gonzaga   WCC  37  33  ...   72.0   7.0          E8   1.0
# 1                 Virginia   ACC  38  35  ...   60.7  11.1   Champions   1.0
# 2                     Duke   ACC  38  32  ...   73.6  11.2          E8   1.0
# 3           North Carolina   ACC  36  29  ...   76.0  10.0         S16   1.0
# 4                 Michigan   B10  37  30  ...   65.9   9.2         S16   2.0
# ..                     ...   ...  ..  ..  ...    ...   ...         ...   ...
# 63        North Dakota St.   Sum  33  19  ...   66.5  -8.6         R64  16.0
# 64                    Iona  MAAC  33  17  ...   71.9 -10.4         R64  16.0
# 65        Prairie View A&M  SWAC  34  22  ...   72.2  -7.1         R68  16.0
# 66     Fairleigh Dickinson   NEC  33  21  ...   68.0  -9.3         R64  16.0
# 67  North Carolina Central  MEAC  31  18  ...   66.4 -10.9         R68  16.0
#
# [68 rows x 23 columns]

# %%
df_college_2018.dropna(['SEED'] == 'NaN')
# Out:
#                        TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0                 Villanova    BE  40  36  ...   69.6  10.6   Champions   1.0
# 1                  Virginia   ACC  34  31  ...   60.5  11.3         R64   1.0
# 2                      Duke   ACC  37  29  ...   70.9   6.6          E8   2.0
# 3                    Purdue   B10  37  30  ...   68.7   7.6         S16   2.0
# 4                Cincinnati  Amer  36  31  ...   66.2   5.9         R32   2.0
# ..                      ...   ...  ..  ..  ...    ...   ...         ...   ...
# 171       Cal St. Fullerton    BW  30  20  ...   70.7  -5.5         R64  15.0
# 182                 Radford  BSth  34  23  ...   64.2  -6.5         R64  16.0
# 257            LIU Brooklyn   NEC  34  18  ...   72.8 -13.2         R68  16.0
# 258          Texas Southern  SWAC  36  16  ...   72.6 -10.9         R64  16.0
# 323  North Carolina Central  MEAC  32  19  ...   66.4 -12.0         R68  16.0
#
# [68 rows x 23 columns]

# %%
df_college_2017.dropna(['SEED'] == 'NaN')
# Out:
#                 TEAM  CONF   G   W  ADJOE  ...  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 0            Gonzaga   WCC  39  37  117.8  ...  29.0   71.5   7.7         2ND   1.0
# 1     North Carolina   ACC  39  33  121.0  ...  33.9   72.8   8.4   Champions   1.0
# 2          Villanova    BE  36  32  122.2  ...  31.1   65.6  11.1         R32   1.0
# 3             Kansas   B12  36  31  121.5  ...  35.6   71.4  11.0          E8   1.0
# 4           Kentucky   SEC  38  32  118.3  ...  30.6   73.7   9.0          E8   2.0
# ..               ...   ...  ..  ..    ...  ...   ...    ...   ...         ...   ...
# 63  South Dakota St.   Sum  33  18  108.2  ...  36.9   68.5  -9.8         R64  16.0
# 64       New Orleans  Slnd  29  20   99.6  ...  31.9   67.7  -6.3         R68  16.0
# 65  Mount St. Mary's   NEC  36  20   98.9  ...  34.1   68.3  -7.9         R64  16.0
# 66          UC Davis    BW  34  23   97.4  ...  32.6   70.3  -7.5         R64  16.0
# ...

# %%
df_college_2021.shape[0]
# Out:
# 347

# %%
df_college_2021.shape[1]
# Out:
# 22

# %%
df_college_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 22 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TEAM     347 non-null    object
#  1   CONF     347 non-null    object
#  2   G        347 non-null    int64
#  3   W        347 non-null    int64
#  4   ADJOE    347 non-null    float64
#  5   ADJDE    347 non-null    float64
#  6   BARTHAG  347 non-null    float64
#  7   EFG_O    347 non-null    float64
#  8   EFG_D    347 non-null    float64
#  9   TOR      347 non-null    float64
#  10  TORD     347 non-null    float64
#  11  ORB      347 non-null    float64
#  12  DRB      347 non-null    float64
#  13  FTR      347 non-null    float64
#  14  FTRD     347 non-null    float64
#  15  2P_O     347 non-null    float64
#  16  2P_D     347 non-null    float64
#  17  3P_O     347 non-null    float64
#  18  3P_D     347 non-null    float64
#  19  ADJ_T    347 non-null    float64
# ...

# %%
df_college_2021.describe()
# Out:
#                 G           W       ADJOE  ...       ADJ_T         WAB       SEED
# count  347.000000  347.000000  347.000000  ...  347.000000  347.000000  68.000000
# mean    22.221902   12.060519  101.921902  ...   68.428530   -5.816715   8.794118
# std      4.040944    5.273373    7.264347  ...    2.689837    5.278143   4.698551
# min      5.000000    0.000000   80.000000  ...   59.900000  -17.800000   1.000000
# 25%     20.000000    8.500000   97.200000  ...   66.500000   -9.400000   5.000000
# 50%     23.000000   12.000000  101.700000  ...   68.300000   -6.100000   9.000000
# 75%     25.000000   16.000000  106.700000  ...   70.300000   -2.500000  13.000000
# max     30.000000   26.000000  125.400000  ...   77.100000    8.900000  16.000000
#
# [8 rows x 20 columns]

# %%
df_college_2021.head(10)
# Out:
#             TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T  WAB  SEED
# 0       Michigan   B10  24  20  118.1  ...  38.7  33.5   66.9  7.2   1.0
# 1         Baylor   B12  24  22  123.2  ...  41.8  34.0   68.8  6.6   1.0
# 2       Illinois   B10  29  23  117.7  ...  37.6  32.7   70.7  8.9   1.0
# 3        Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6  8.5   1.0
# 4           Iowa   B10  29  21  123.5  ...  38.6  34.8   70.0  5.6   2.0
# 5       Ohio St.   B10  30  21  122.1  ...  36.5  34.1   66.9  6.0   2.0
# 6        Houston  Amer  26  24  120.6  ...  35.5  28.5   65.0  4.0   2.0
# 7        Alabama   SEC  30  24  111.0  ...  35.1  28.8   73.9  6.8   2.0
# 8  West Virginia   B12  27  18  115.9  ...  35.7  32.3   69.6  3.0   3.0
# 9          Texas   B12  26  19  113.8  ...  35.7  32.3   69.1  4.2   3.0
#
# [10 rows x 22 columns]

# %%
df_college_2021.tail(10)
# Out:
#                  TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T  WAB  SEED
# 337         UC Irvine    BW  25  18   99.0  ...  32.9  32.9   67.8 -3.7   NaN
# 338  Jacksonville St.   OVC  25  18  104.5  ...  34.6  32.7   66.1 -5.2   NaN
# 339   Sam Houston St.  Slnd  24  19  100.4  ...  34.8  30.3   71.0 -4.4   NaN
# 340     Southern Utah  BSky  19  20  106.6  ...  33.4  35.8   70.3 -1.7   NaN
# 341  Western Kentucky  CUSA  27  20  104.6  ...  34.5  35.8   68.1 -0.4   NaN
# 342    Louisiana Tech  CUSA  27  21  102.7  ...  34.6  29.6   69.6 -1.7   NaN
# 343            Toledo   MAC  29  21  113.3  ...  37.7  29.5   69.1 -2.1   NaN
# 344               UAB  CUSA  27  22  102.5  ...  31.1  32.4   67.5 -2.7   NaN
# 345  Eastern Kentucky   OVC  27  22  101.5  ...  35.8  33.0   75.1 -3.8   NaN
# 346           Belmont   OVC  29  26  108.5  ...  34.7  34.0   71.1 -1.1   NaN
#
# [10 rows x 22 columns]

# %%
df_college_2021.sample(10)
# Out:
#                       TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 53                 Liberty  ASun  24  23  109.1  ...  38.8  32.2   63.4  -1.7  13.0
# 163                Niagara  MAAC  20   9   98.8  ...  31.3  33.9   65.0  -8.8   NaN
# 160  College of Charleston   CAA  17   9  102.4  ...  38.2  36.6   64.0  -7.4   NaN
# 195                 Tulane  Amer  23  10   98.7  ...  29.8  35.8   67.3  -5.9   NaN
# 15            Oklahoma St.   B12  28  20  109.3  ...  33.8  31.7   71.6   4.6   4.0
# 142          East Carolina  Amer  18   8   98.4  ...  29.8  31.9   68.3  -6.2   NaN
# 330                 Mercer    SC  26  18  105.2  ...  36.6  31.4   67.9  -6.3   NaN
# 251                Oakland  Horz  30  12  102.8  ...  33.3  37.3   70.3 -11.5   NaN
# 179                    FIU  CUSA  22   9   96.5  ...  32.7  36.9   70.6 -13.7   NaN
# 46              Georgetown    BE  25  13  108.5  ...  36.6  32.6   69.5  -1.0  12.0
#
# [10 rows x 22 columns]

# %%
df_college_2021.sort_values('TOR', ascending = False)
# Out:
#                        TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 71                    Maine    AE   9   2   85.2  ...  31.5  30.9   65.8  -5.7   NaN
# 75   Mississippi Valley St.  SWAC  24   2   80.0  ...  32.9  35.8   72.3 -17.5   NaN
# 70                    Idaho  BSky  22   1   91.7  ...  34.1  38.1   67.2 -17.8   NaN
# 103        Central Arkansas  Slnd  23   5   97.3  ...  36.0  38.2   71.4 -13.3   NaN
# 104  Texas A&M Corpus Chris  Slnd  21   5   90.2  ...  33.3  34.4   69.5 -15.9   NaN
# ..                      ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 54                  Colgate   Pat  15  14  110.8  ...  40.2  26.1   71.9   0.3  14.0
# 281           Bowling Green   MAC  24  14  104.5  ...  31.8  34.1   70.5  -5.5   NaN
# 34                Wisconsin   B10  29  17  111.3  ...  36.0  33.0   65.0   2.2   9.0
# 16                Villanova    BE  22  16  117.9  ...  35.2  35.4   65.1   3.2   5.0
# ...

# %%
df_college_2021.sort_values('TOR', ascending = True)
# Out:
#                        TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 4                      Iowa   B10  29  21  123.5  ...  38.6  34.8   70.0   5.6   2.0
# 16                Villanova    BE  22  16  117.9  ...  35.2  35.4   65.1   3.2   5.0
# 34                Wisconsin   B10  29  17  111.3  ...  36.0  33.0   65.0   2.2   9.0
# 281           Bowling Green   MAC  24  14  104.5  ...  31.8  34.1   70.5  -5.5   NaN
# 54                  Colgate   Pat  15  14  110.8  ...  40.2  26.1   71.9   0.3  14.0
# ..                      ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 145             Florida A&M  MEAC  20   8   89.1  ...  31.4  28.5   68.3  -8.8   NaN
# 103        Central Arkansas  Slnd  23   5   97.3  ...  36.0  38.2   71.4 -13.3   NaN
# 70                    Idaho  BSky  22   1   91.7  ...  34.1  38.1   67.2 -17.8   NaN
# 75   Mississippi Valley St.  SWAC  24   2   80.0  ...  32.9  35.8   72.3 -17.5   NaN
# ...

# %%
df_college_2017.sort_values('W', ascending = False)
# Out:
#                    TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0               Gonzaga   WCC  39  37  ...   71.5   7.7         2ND   1.0
# 1        North Carolina   ACC  39  33  ...   72.8   8.4   Champions   1.0
# 8                Oregon   P12  38  33  ...   68.4   6.0          F4   3.0
# 2             Villanova    BE  36  32  ...   65.6  11.1         R32   1.0
# 4              Kentucky   SEC  38  32  ...   73.7   9.0          E8   2.0
# ..                  ...   ...  ..  ..  ...    ...   ...         ...   ...
# 263          Oregon St.   P12  31   5  ...   66.3 -16.7         NaN   NaN
# 349        Presbyterian  BSth  28   5  ...   65.3 -20.5         NaN   NaN
# 345      St. Francis NY   NEC  30   4  ...   68.5 -22.5         NaN   NaN
# 347  North Carolina A&T  MEAC  30   3  ...   64.6 -25.2         NaN   NaN
# 350         Alabama A&M  SWAC  29   2  ...   65.7 -24.0         NaN   NaN
#
# [351 rows x 23 columns]

# %%
df_college_2018.sort_values('W', ascending = False)
# Out:
#                  TEAM  CONF   G   W  ADJOE  ...  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 0           Villanova    BE  40  36  128.4  ...  31.7   69.6  10.6   Champions   1.0
# 6            Michigan   B10  40  33  114.4  ...  33.2   65.9   6.9         2ND   3.0
# 12            Gonzaga   WCC  37  32  117.2  ...  35.0   70.5   4.9         S16   4.0
# 40     Loyola Chicago   MVC  37  32  110.5  ...  32.0   66.4   2.0          F4  11.0
# 5              Kansas   B12  39  31  122.1  ...  33.3   69.9   8.2          F4   1.0
# ..                ...   ...  ..  ..    ...  ...   ...    ...   ...         ...   ...
# 344  Northwestern St.  Slnd  25   4   88.2  ...  37.2   70.5 -18.1         NaN   NaN
# 293      San Jose St.   MWC  29   4   95.5  ...  35.4   68.3 -18.5         NaN   NaN
# 343       Chicago St.   WAC  30   3   94.9  ...  40.6   73.4 -20.3         NaN   NaN
# 349       Alabama A&M  SWAC  31   3   87.6  ...  38.4   67.5 -23.0         NaN   NaN
# ...

# %%
df_college_2019.sort_values('W', ascending = False)
# Out:
#               TEAM  CONF   G   W  ADJOE  ...  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 1         Virginia   ACC  38  35  123.0  ...  28.9   60.7  11.1   Champions   1.0
# 0          Gonzaga   WCC  37  33  123.4  ...  30.4   72.0   7.0          E8   1.0
# 10         Houston  Amer  37  33  115.7  ...  27.9   67.3   7.8         S16   3.0
# 22         Buffalo   MAC  35  32  113.6  ...  29.3   74.9   5.5         R32   6.0
# 2             Duke   ACC  38  32  118.9  ...  29.9   73.6  11.2          E8   1.0
# ..             ...   ...  ..  ..    ...  ...   ...    ...   ...         ...   ...
# 336    USC Upstate  BSth  29   5   92.7  ...  34.3   69.5 -20.8         NaN   NaN
# 338   San Jose St.   MWC  30   4   92.7  ...  37.3   71.0 -20.3         NaN   NaN
# 343  UNC Asheville  BSth  28   4   93.1  ...  36.2   63.7 -20.8         NaN   NaN
# 263         Tulane  Amer  31   4   97.0  ...  33.6   71.2 -17.2         NaN   NaN
# ...

# %%
df_college_2020.sort_values('W', ascending = False)
# Out:
#       RK                    TEAM  CONF   G   W  ...  2P_D  3P_O  3P_D  ADJ_T   WAB
# 2      3                 Gonzaga   WCC  33  31  ...  47.4  38.6  32.0   72.0   7.7
# 75    76      East Tennessee St.    SC  31  30  ...  51.1  33.9  31.7   66.0   2.5
# 9     10           San Diego St.   MWC  31  30  ...  45.3  37.9  30.1   64.7   6.7
# 78    79                 Liberty  ASun  32  30  ...  45.9  35.0  30.0   61.3  -0.3
# 3      4                  Dayton   A10  31  29  ...  45.1  37.1  33.0   67.5   6.8
# ..   ...                     ...   ...  ..  ..  ...   ...   ...   ...    ...   ...
# 333  334         Houston Baptist  Slnd  29   4  ...  58.4  36.4  38.4   76.1 -18.1
# 350  351  Mississippi Valley St.  SWAC  30   4  ...  55.5  29.4  34.1   77.4 -22.2
# 352  353             Chicago St.   WAC  26   4  ...  55.3  30.4  40.6   69.2 -20.0
# 343  344              Holy Cross   Pat  31   3  ...  55.6  32.0  37.6   68.3 -24.1
# ...

# %%
df_college_2021.sort_values('W', ascending = False)
# Out:
#                        TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 346                 Belmont   OVC  29  26  108.5  ...  34.7  34.0   71.1  -1.1   NaN
# 3                   Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6   8.5   1.0
# 45                    Drake   MVC  27  25  111.8  ...  36.6  30.8   66.7   1.5  11.0
# 31           Loyola Chicago   MVC  26  24  108.5  ...  35.7  32.5   63.9   1.7   8.0
# 6                   Houston  Amer  26  24  120.6  ...  35.5  28.5   65.0   4.0   2.0
# ..                      ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 75   Mississippi Valley St.  SWAC  24   2   80.0  ...  32.9  35.8   72.3 -17.5   NaN
# 70                    Idaho  BSky  22   1   91.7  ...  34.1  38.1   67.2 -17.8   NaN
# 69       South Carolina St.  MEAC  18   1   86.5  ...  31.9  36.1   72.7 -14.7   NaN
# 68                   Howard  MEAC   5   1   95.8  ...  34.6  33.9   70.8  -3.4   NaN
# ...

# %%
df_college_2019.sort_values('EFG_O', ascending = False)
# Out:
#                        TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 0                   Gonzaga   WCC  37  33  ...   72.0   7.0          E8   1.0
# 108        South Dakota St.   Sum  32  24  ...   72.4  -3.4         NaN   NaN
# 42                  Belmont   OVC  32  27  ...   72.5   1.2         R64  11.0
# 25                  Wofford    SC  32  30  ...   67.1   4.0         R32   7.0
# 52             Northeastern   CAA  34  23  ...   67.5  -2.8         R64  13.0
# ..                      ...   ...  ..  ..  ...    ...   ...         ...   ...
# 339              Morgan St.  MEAC  28   9  ...   73.6 -17.3         NaN   NaN
# 352  Maryland Eastern Shore  MEAC  30   7  ...   64.5 -19.9         NaN   NaN
# 347  Mississippi Valley St.  SWAC  31   6  ...   70.6 -20.2         NaN   NaN
# 335            Kennesaw St.  ASun  30   5  ...   69.6 -18.6         NaN   NaN
# 351            Delaware St.  MEAC  29   6  ...   71.6 -21.7         NaN   NaN
#
# [353 rows x 23 columns]

# %%
df_college_2020.sort_values('EFG_O', ascending = False)
# Out:
#       RK                    TEAM  CONF   G   W  ...  2P_D  3P_O  3P_D  ADJ_T   WAB
# 3      4                  Dayton   A10  31  29  ...  45.1  37.1  33.0   67.5   6.8
# 16    17                     BYU   WCC  31  24  ...  50.8  41.9  30.3   69.4   2.7
# 2      3                 Gonzaga   WCC  33  31  ...  47.4  38.6  32.0   72.0   7.7
# 132  133        South Dakota St.   Sum  30  22  ...  49.2  35.4  30.7   68.0  -4.6
# 68    69             North Texas  CUSA  29  20  ...  47.8  37.5  35.5   63.0  -3.5
# ..   ...                     ...   ...  ..  ..  ...   ...   ...   ...    ...   ...
# 348  349     Arkansas Pine Bluff  SWAC  29   4  ...  50.2  26.3  31.1   66.1 -20.0
# 350  351  Mississippi Valley St.  SWAC  30   4  ...  55.5  29.4  34.1   77.4 -22.2
# 345  346             Alabama A&M  SWAC  30   8  ...  52.7  28.1  32.4   68.1 -17.6
# 349  350  Maryland Eastern Shore  MEAC  31   5  ...  51.3  25.0  33.7   67.7 -20.8
# ...

# %%
df_college_2021.sort_values('EFG_O', ascending = False)
# Out:
#                      TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 3                 Gonzaga   WCC  26  26  125.4  ...  36.5  32.5   74.6   8.5   1.0
# 149            Fort Wayne  Horz  23   8  100.3  ...  40.0  33.6   69.7 -12.7   NaN
# 1                  Baylor   B12  24  22  123.2  ...  41.8  34.0   68.8   6.6   1.0
# 53                Liberty  ASun  24  23  109.1  ...  38.8  32.2   63.4  -1.7  13.0
# 54                Colgate   Pat  15  14  110.8  ...  40.2  26.1   71.9   0.3  14.0
# ..                    ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 89    Arkansas Pine Bluff  SWAC  25   4   90.4  ...  30.8  40.0   67.9 -16.0   NaN
# 162  UT Rio Grande Valley   WAC  15   9   90.4  ...  26.7  31.6   70.5  -7.8   NaN
# 132             Manhattan  MAAC  20   7   91.7  ...  26.4  33.0   67.1 -11.2   NaN
# 72                Fordham   A10  14   2   87.5  ...  26.9  33.4   63.5  -8.2   NaN
# ...

# %%
df_college_2018.sort_values('3P_O', ascending = False)
# Out:
#                        TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 167          William & Mary   CAA  29  19  ...   71.0  -6.2         NaN   NaN
# 3                    Purdue   B10  37  30  ...   68.7   7.6         S16   2.0
# 41                Marquette    BE  35  21  ...   70.4   1.0         NaN   NaN
# 152                   Idaho  BSky  29  22  ...   66.8  -4.5         NaN   NaN
# 169               Weber St.  BSky  28  20  ...   68.5  -6.1         NaN   NaN
# ..                      ...   ...  ..  ..  ...    ...   ...         ...   ...
# 329                   Maine    AE  30   6  ...   72.2 -20.2         NaN   NaN
# 288                 Fordham   A10  31   9  ...   67.2 -14.9         NaN   NaN
# 240              California   P12  31   8  ...   69.9 -13.3         NaN   NaN
# 344        Northwestern St.  Slnd  25   4  ...   70.5 -18.1         NaN   NaN
# 348  Maryland Eastern Shore  MEAC  30   7  ...   66.4 -19.3         NaN   NaN
#
# [351 rows x 23 columns]

# %%
df_college_2019.sort_values('3P_O', ascending = False)
# Out:
#                        TEAM  CONF   G   W  ...  ADJ_T   WAB  POSTSEASON  SEED
# 181                  Lehigh   Pat  31  20  ...   72.9  -5.5         NaN   NaN
# 25                  Wofford    SC  32  30  ...   67.1   4.0         R32   7.0
# 108        South Dakota St.   Sum  32  24  ...   72.4  -3.4         NaN   NaN
# 277           Grambling St.  SWAC  31  17  ...   70.7 -11.5         NaN   NaN
# 66      Fairleigh Dickinson   NEC  33  21  ...   68.0  -9.3         R64  16.0
# ..                      ...   ...  ..  ..  ...    ...   ...         ...   ...
# 238           East Carolina  Amer  31  10  ...   69.9 -12.3         NaN   NaN
# 143            Rhode Island   A10  33  18  ...   68.9  -6.8         NaN   NaN
# 341        Northwestern St.  Slnd  28  11  ...   69.9 -14.9         NaN   NaN
# 321             Jackson St.  SWAC  30  13  ...   67.0 -14.5         NaN   NaN
# 352  Maryland Eastern Shore  MEAC  30   7  ...   64.5 -19.9         NaN   NaN
#
# [353 rows x 23 columns]

# %%
df_college_2020.sort_values('3P_O', ascending = False)
# Out:
#       RK                    TEAM  CONF   G   W  ...  2P_D  3P_O  3P_D  ADJ_T   WAB
# 16    17                     BYU   WCC  31  24  ...  50.8  41.9  30.3   69.4   2.7
# 17    18                  Oregon   P12  31  24  ...  46.2  39.6  32.6   65.2   4.7
# 233  234                UC Davis    BW  30  14  ...  55.0  39.1  35.0   67.9 -12.8
# 179  180            South Dakota   Sum  29  20  ...  50.7  38.8  36.6   69.8  -7.1
# 40    41            Saint Mary's   WCC  33  25  ...  50.7  38.8  34.0   63.8   2.8
# ..   ...                     ...   ...  ..  ..  ...   ...   ...   ...    ...   ...
# 193  194        Eastern Michigan   MAC  28  16  ...  47.9  26.7  34.2   66.7  -9.1
# 258  259             Jackson St.  SWAC  30  14  ...  47.7  26.3  33.8   68.7 -12.0
# 348  349     Arkansas Pine Bluff  SWAC  29   4  ...  50.2  26.3  31.1   66.1 -20.0
# 349  350  Maryland Eastern Shore  MEAC  31   5  ...  51.3  25.0  33.7   67.7 -20.8
# ...

# %%
df_college_2021.sort_values('3P_O', ascending = False)
# Out:
#                      TEAM  CONF   G   W  ADJOE  ...  3P_O  3P_D  ADJ_T   WAB  SEED
# 1                  Baylor   B12  24  22  123.2  ...  41.8  34.0   68.8   6.6   1.0
# 320      South Dakota St.   Sum  22  16  108.6  ...  40.9  35.5   71.3  -3.2   NaN
# 54                Colgate   Pat  15  14  110.8  ...  40.2  26.1   71.9   0.3  14.0
# 149            Fort Wayne  Horz  23   8  100.3  ...  40.0  33.6   69.7 -12.7   NaN
# 257           Cal Baptist   WAC  19  13  104.8  ...  39.6  36.8   70.6  -7.2   NaN
# ..                    ...   ...  ..  ..    ...  ...   ...   ...    ...   ...   ...
# 72                Fordham   A10  14   2   87.5  ...  26.9  33.4   63.5  -8.2   NaN
# 120            New Mexico   MWC  20   6   93.3  ...  26.8  34.9   67.4 -11.2   NaN
# 162  UT Rio Grande Valley   WAC  15   9   90.4  ...  26.7  31.6   70.5  -7.8   NaN
# 132             Manhattan  MAAC  20   7   91.7  ...  26.4  33.0   67.1 -11.2   NaN
# ...

# %% [markdown]
# We were able to see that a great shooting percentage could attribute to the amount of games won. But when 3 point percentage is considered, that is not the case. Take Gonzaga, for example, they excelled in the field goal percentage range and that behavior transpired to their games won. But they were not so hot in the 3 point.

# %%
df_most_college_wins_2013 = df_college_2013.groupby('TEAM').agg({'W': 'max'})
df_most_college_wins_2013
# Out:
#                  W
# TEAM
# Air Force       16
# Akron           25
# Alabama         22
# Alabama A&M      9
# Alabama St.      9
# ...             ..
# Wright St.      22
# Wyoming         18
# Xavier          17
# Yale            12
# Youngstown St.  15
#
# [347 rows x 1 columns]

# %%
df_most_college_wins_2014 = df_college_2014.groupby('TEAM').agg({'W': 'max'})
df_most_college_wins_2014
# Out:
#                     W
# TEAM
# Abilene Christian   2
# Air Force          10
# Akron              21
# Alabama            12
# Alabama A&M        12
# ...                ..
# Wright St.         19
# Wyoming            16
# Xavier             21
# Yale               18
# Youngstown St.     12
#
# [351 rows x 1 columns]

# %%
df_most_college_wins_2015 = df_college_2015.groupby('TEAM').agg({'W': 'max'})
df_most_college_wins_2015
# Out:
#                     W
# TEAM
# Abilene Christian   7
# Air Force          12
# Akron              20
# Alabama            18
# Alabama A&M         8
# ...                ..
# Wright St.          9
# Wyoming            23
# Xavier             23
# Yale               20
# Youngstown St.      8
#
# [351 rows x 1 columns]

# %%
conference_of_2021_wins = df_college_2021.groupby('CONF', as_index=False).agg({'W': ['count', 'sum', 'mean', 'max']})
conference_of_2021_wins
# Out:
#     CONF     W
#          count  sum       mean max
# 0    A10    14  150  10.714286  19
# 1    ACC    15  196  13.066667  18
# 2     AE    10   89   8.900000  15
# 3   ASun     9  109  12.111111  23
# 4   Amer    11  133  12.090909  24
# 5    B10    14  219  15.642857  23
# 6    B12    10  154  15.400000  22
# 7     BE    11  148  13.454545  20
# 8   BSky    11  129  11.727273  20
# 9   BSth    11  123  11.181818  23
# 10    BW    11  122  11.090909  22
# 11   CAA    10   92   9.200000  13
# 12  CUSA    14  196  14.000000  22
# 13  Horz    12  137  11.416667  19
# 14  MAAC    11  110  10.000000  14
# 15   MAC    12  140  11.666667  21
# 16  MEAC     9   68   7.555556  16
# 17   MVC    10  141  14.100000  25
# 18   MWC    11  149  13.545455  23
# 19   NEC    10   96   9.600000  15
# 20   OVC    12  162  13.500000  26
# 21   P12    12  180  15.000000  22
# 22   Pat    10   81   8.100000  15
# 23    SB    12  167  13.916667  18
# 24    SC    10  144  14.400000  21
# ...

# %%
df_stats_by_conf_2021 = df_college_2021.groupby('CONF', as_index=False).agg({
    'G': 'sum',
    'W': 'sum',
    'EFG_O': 'mean',
    'EFG_D': 'mean'
})

df_stats_by_conf_2021['WINNING_PCT']= df_stats_by_conf_2021['W'] / df_stats_by_conf_2021['G']

df_stats_by_conf_2021
# Out:
#     CONF    G    W      EFG_O      EFG_D  WINNING_PCT
# 0    A10  283  150  50.178571  49.578571     0.530035
# 1    ACC  351  196  51.306667  50.373333     0.558405
# 2     AE  183   89  48.690000  49.110000     0.486339
# 3   ASun  187  109  50.988889  51.422222     0.582888
# 4   Amer  230  133  48.127273  47.745455     0.578261
# 5    B10  379  219  50.685714  48.621429     0.577836
# 6    B12  262  154  50.660000  49.260000     0.587786
# 7     BE  269  148  50.236364  49.072727     0.550186
# 8   BSky  223  129  50.136364  51.318182     0.578475
# 9   BSth  259  123  50.318182  50.890909     0.474903
# 10    BW  222  122  49.972727  50.590909     0.549550
# 11   CAA  178   92  49.670000  50.350000     0.516854
# 12  CUSA  328  196  50.050000  49.807143     0.597561
# 13  Horz  278  137  51.183333  51.958333     0.492806
# 14  MAAC  225  110  47.563636  47.754545     0.488889
# 15   MAC  260  140  50.208333  51.133333     0.538462
# ...

# %%
df_college_2012.head(1)
# Out:
#              TEAM CONF   G   W  ADJOE  ...  ADJ_T  WAB  POSTSEASON  SEED  YEAR
# 0  North Carolina  ACC  40  33  123.3  ...   71.7  8.6         2ND   1.0  2016
#
# [1 rows x 24 columns]

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
fig = px.box(df_college_2021[df_college_2021['W'] < 30],
             x='W',
             orientation='h',
             title='Amount of Wins less than 30 by Division 1 Team 2021')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c45fe6d8-2bf6-4546-b035-6de8747011aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c45fe6d8-2bf6-4546-b035-6de8747011aa")) {
#                     Plotly.newPlot(
#                         'c45fe6d8-2bf6-4546-b035-6de8747011aa',
# ...

# %%
fig = px.histogram(df_college_2020, x='W', title='Amount of Wins 2020', nbins=36)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="231da245-ab5b-45ba-b807-e8fcb2e818cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("231da245-ab5b-45ba-b807-e8fcb2e818cf")) {
#                     Plotly.newPlot(
#                         '231da245-ab5b-45ba-b807-e8fcb2e818cf',
# ...

# %%
fig = px.scatter(df_college_2021, x='3P_O', y='W', title= 'Number of Wins to Number of Games')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e2eafeea-e81a-4628-9a29-464989b3f91d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2eafeea-e81a-4628-9a29-464989b3f91d")) {
#                     Plotly.newPlot(
#                         'e2eafeea-e81a-4628-9a29-464989b3f91d',
# ...

# %% [markdown]
# This is a moderately strong linear relationship between the amount of 3 pointers made and games won. The higher amount of 3 pointers made translates to a higher amount of games won.

# %%
fig = px.bar(df_college_2021, x='2P_O', y='W', title='Number of Wins to Number of Games')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="97bbe836-f4ab-444f-941b-bfe7d888543c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("97bbe836-f4ab-444f-941b-bfe7d888543c")) {
#                     Plotly.newPlot(
#                         '97bbe836-f4ab-444f-941b-bfe7d888543c',
# ...

# %% [markdown]
# The highest amount of games won came from average 2 point feild goal percentages.

# %%
fig = px.scatter(
    df_college_2021,
    title='Number of Wins to Games Plot',
    x="W",
    y="3P_O",
    size="G",
    color="CONF",
    template='plotly_dark',
    width=800,
    height=400
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fe12e65e-7014-4cd6-9ce8-ddb3b29b9b97" class="plotly-graph-div" style="height:400px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fe12e65e-7014-4cd6-9ce8-ddb3b29b9b97")) {
#                     Plotly.newPlot(
#                         'fe12e65e-7014-4cd6-9ce8-ddb3b29b9b97',
# ...

# %%
fig = px.density_heatmap(
    df_college_2021,
    x='CONF',
    y='W',
    title='Conference vs Wins',
    height=600
)
fig.show()
# YOUR CODE ENDS
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ba0899e0-fa34-4bf3-bd33-0c1fc8471319" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ba0899e0-fa34-4bf3-bd33-0c1fc8471319")) {
#                     Plotly.newPlot(
#                         'ba0899e0-fa34-4bf3-bd33-0c1fc8471319',
# ...

# %%
fig = px.pie(
    df_college_2021,
    names='CONF',
    title='Conference breakdown',
    width=800,
    height=700)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dc4da0b3-9c35-4c58-8719-1c977e86bb59" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dc4da0b3-9c35-4c58-8719-1c977e86bb59")) {
#                     Plotly.newPlot(
#                         'dc4da0b3-9c35-4c58-8719-1c977e86bb59',
# ...

# %% [markdown]
# This pie chart shows the make-up percentage of teams per conference.

# %%
fig = px.bar(
   df_college_2021,
    x='CONF',
    y='3P_O',
    color='W',
    template='plotly_dark',
    title='Wins Breakdown by Games and Conference',
    height=600
)

fig.update_yaxes(categoryorder='total ascending')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="03896374-78f2-4e52-b77f-a302e34c0fe4" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03896374-78f2-4e52-b77f-a302e34c0fe4")) {
#                     Plotly.newPlot(
#                         '03896374-78f2-4e52-b77f-a302e34c0fe4',
# ...

# %% [markdown]
# Above is a breakdwon of conferences with respect to their 3 point percentage and games won.

# %% [markdown]
# Gonzaga has made face already in most games won. We see that there is an association with the highest fielg goa percentage and games won as Gonzaga has been top of the list twice out of the most recent past three years adressed. We can conclude that there is a correlation between a high field goal percentage and a high winning of games. From the codes above, I was able to make a code that answered my question of which team had the highest/lowest turnover rate. Iowa had the lowest turnover rate whereas Maine had te highest. As we can see from the codes above, Gonzaga has been consistent in being the within the top three when 'most games won' are in discussion. Giving Loyola Chicago the second award for maintaining a top 5 spot for the most recent two years out of the five years adressed.
# I was able to make an aggregations which allowed me to view the count, sum, mean, and max of wins by conference. I was also able to aggregate data from 2013 - 2015 to get the highest number of wins by team.
# From th many visualizations offered, I was able to visualize the relationships between wins and games. Some plots, like the pie chart, I was able to visualize a conference breakdown by its size. Most of my data refers to the 2021 season as it was the most exciting and unpredictable season of all amidst a pandemic.
